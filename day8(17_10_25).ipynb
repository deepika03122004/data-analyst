# %% [markdown]
# **pandas:**designed for data manipulation and analysis.
# 1. A DataFrame is a 2-dimensional, labeled data structure in Pandas
# index (rows) and columns
# 2.  Pandas allows us to analyze big data and make conclusions based on statistical theories

# %% [markdown]
# **pandas**

# %%
import pandas as pd

# %%
df=pd.read_csv(r"/content/dataset.csv", encoding='latin1')
df
# Out:
#                                                  NAME  AGE  GENDER ILLNESS  \
# 0                                        Rajesh Kumar   20    male   fever
# 1                                          Neha Sinha   13  female   cough
# 2                                         Arjun Singh   45    male   fever
# 3                                          Ravi Patel   45    male   cough
# 4                                         Suresh Babu   45    male   fever
# 5                                         Vijay Reddy   45    male   fever
# 6                                        Manoj Sharma   45    male   fever
# 7                                              deepak   45    male   fever
# 8                                        Sanjay Yadav   45    male   cough
# 9   Priya Sharma\nDeepa Nair\nLakshmi Reddy\n Anja...   45  female   fever
# 10                                       Priya Sharma   45  female   fever
# ...

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# missing values

# %%
d={
    'A': [1,2, np.nan,4],
    'B':[5, np.nan, np.nan,4],
    'C':[1,2,3,4]
    }
df=pd.DataFrame(d)
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4
